# %%
import torch
from pytorch_pretrained_bert import BertTokenizer, BertForNextSentencePrediction
from Terry_toolkit import Text

# %%
tokeniser = BertTokenizer.from_pretrained('bert-base-chinese')
model = BertForNextSentencePrediction.from_pretrained('bert-base-chinese')

# %%
# 输入一个段落，分成句子，可使用split函数来实现
paragraph = '''

酒吧里昏暗迷离，年轻男女们高歌曼舞尽情狂欢，酒后兴起玩幼稚游戏。

　　轮到陈乘大冒险，众人起哄和女伴打kiss。

　　林燕薇坐在一旁冷眼旁观，只见他晃晃悠悠起身走向别人，却骤然一转扭头捧住了她的脸。

　　突然的吻没有防备，抬眸便是他深邃的眉眼。

　　唇一触即离，不等林燕薇动手陈乘就主动退开，眼神迷离，笑容无辜又灿烂。

　　“对不起我喝多了，好像认错人了呢。”

　　当夜，林燕薇半梦半醒看窗外，男人正坐在她家窗户上吹冷风，指尖烟火明灭，发丝随风飞扬。

　　她起身过去关窗赶人，冷笑一声：“看来真的是喝多了，不仅人认错，连门都认错了。

　　“门没错，人也没错——”

　　醉鬼却轰然倒在她身上，边胡乱亲她边可怜兮兮，“只是喝多了，更想你了……”

　　内容标签：豪门世家 情有独钟 天作之合 娱乐圈

　　主角：陈乘，林燕薇 ┃ 配角： ┃ 其它：

第一章

　　英国，剑桥。

　　刚刚下过一场雨，天色阴沉，人的心情也跟着有些沉闷。

　　图书馆门口人来人往，步履匆匆，偶尔微笑点头致意，继而又抱着各自的东西奔赴忙碌之中。

　　师生们一一持卡而入，井然有序，一旁的保安小哥百无聊赖，趁人不注意扭头打了个哈欠。

　　然而这一扭头，保安小哥无神的眼突然就亮了起来，哈欠才打了一半，嘴半张着忘了合拢，睁大了双眼呆呆地望着不远处的倩影。

　　只见一个美丽的东方面孔从门口款款走来，身材高挑，皮肤白皙，身着一袭红色吊带长裙，裙摆摇曳，明艳动人，看着她竟觉得她背后灰暗的天空都亮堂起来了。

　　佳人越走越近，小保安连忙捂上嘴打完了哈欠，视线却不舍得移开分毫。在学校他也常常见到亚洲的女学生，但是却没有一个像今天这个女人一样让他惊艳。

　　纯黑色的头发烫成了大大的波浪卷随意地披在肩上，走动间纠缠着那美丽修长的玉颈，细细的红色肩带露出圆润光洁的肩头，和精致漂亮的锁骨形成了流畅的线条。

　　再往下就是一片炫目的白，黑发，红裙，雪肌，极致的黑和极致的红呈现出了最极致的白，V领下的起伏美得令人窒息。

　　美人离自己几步之遥，也不知是不是注意到了他的视线，她突然朝这边笑了笑。

　　红唇醒目，魅惑人心，和身上的红裙完美呼应，诉说着女人的性感和美丽，杀伤力十足。

　　脸上发烫不敢与之对视，保安小哥保安小哥害羞地低了下头，然而眼神却还是不自觉地往美人那里瞄去。

　　红裙长至脚踝，美人脚踩红色高跟鞋，白嫩的脚踝和小半截脚面随着裙摆的晃动若隐若现……

　　小保安忍不住咕咚一声咽了一口口水，从没想过女人的脚踝会这样漂亮，他竟然有种撩起美人长裙的冲动。

　　一步，两步，三步，眼看美人拿着卡就要从自己身边进去，四肢仿佛不听使唤一般，小保安意识到的时候已经拦到了她面前。

　　年轻的保安入职不久，恪守职责，这还是他第一次在工作期间去搭讪女人。

　　美人疑惑地看了过来，那双眼睛清澈、灵动，像是会说话一样，小保安不禁紧张地结巴了起来。

　　想到之前和同伴聊天的时候曾讨论到亚洲的女人都比较委婉含蓄，保安小哥没有直接索要手机号码，而是绞尽脑汁来了一场美丽的开场白。

　　但是结果却没有想象中的美丽，面前的东方美人似乎并不理解他的话，而她说的英语他也不是很懂。

　　到最后两人全靠肢体语言交流，小保安伸出了一只手，另一只手做出了写字的动作，觉得这已经够明显直白了。

　　“I see!”

　　美人一拍手，小保安不禁松了口气，终于说清楚了。

　　然而却见美人脱下了脚上的红色高跟鞋，挥手说了声再见，就拎着鞋子小跑着进去了，只剩下小保安看着她的背影一脸懵逼。

　　***

　　拐进楼梯间，见四周无人，林燕薇赶紧停下揉了揉自己的脚，明明买得时候穿上感觉良好啊，怎么这才一会儿功夫脚就又累又痛。

　　幸好保安提醒，别人都是来图书馆学习研究的，她居然还穿高跟鞋，多打扰人啊，都怪她太兴奋了，只想着打扮得美美的去见陈乘。

　　一想到陈乘，林燕薇的嘴角就不自觉地上扬。她这一个月都特意没去联系他，就是想给他一个惊喜。都大半年没见了，也不知道陈乘看到她是什么表情。

　　不自觉地低头看了看自己的胸，林燕薇的表情有些纠结，往上拽了拽，却觉得不太好看，就又往下拉了拉。

　　林燕薇的脸红扑扑的，整理好衣服又从包里拿出小镜子照了照，这才挺了挺胸，左手轻轻捏着两只高跟鞋做兰花指状，迈着优雅的步伐朝楼上走去。

　　来到一个阅览室，走到第三排书架后面，果然看到了陈乘。此时他正在低头写着什么，桌前摆着几本砖头厚的书籍，林燕薇瞟了眼长长的英文书名，轻轻吐了吐舌头。

　　陈乘写得太过投入，并没有注意到身边多了一个人。对面的座位正好空着，林燕薇就静静坐了过去，双手托腮看着陈乘，眼睛亮晶晶的，和看到偶像的迷妹没什么两样。

　　都说认真的男人最帅了，这话果然不差啊。林燕薇越来越觉得，这世界上再没有比陈乘更帅的男人了。

　　但是太认真了也不好，林燕薇觉得自己屁股都坐疼了，陈乘还在埋头写东西。

　　左摇摇，右晃晃，时不时有男人暧昧的视线投来，林燕薇只觉得没意思，趴在桌上望着陈乘鼓起了嘴。

　　她是主动跟陈乘打招呼呢，还是继续等他发现自己呢？

　　脚没穿鞋子，时间久了凉冰冰的，林燕薇就想着重新穿上鞋。低头的时候看到了陈乘的腿，林燕薇眼睛闪了闪，嘴角微勾有了主意。

　　林燕薇往凳子里面坐了坐，看好角度就将腿伸了过去。然而脚左右晃动，却是寻不到任何阻碍。

　　撇了撇嘴，林燕薇再次弯腰看了看桌下，伸直腿比划了下长度，眉头轻蹙。

　　不该呀，按道理肯定是可以够到的。

　　又重新坐起，这次林燕薇臀部只留在凳子上一点点，费力往前伸，终于碰到了目标。

　　陈乘还是低着头没看她一眼，林燕薇却知道了，陈乘肯定是早就看到她了，刚才故意别开了腿的。

　　直勾勾地盯着陈乘，用脚在他的腿上蹭来蹭去，从小腿蜿蜒而上，最后落在了他的大腿。

　　还没来得及做出动作，林燕薇的脚就被陈乘的手握住，粗粝的手掌摩擦着细嫩的脚背，指尖还在脚心轻勾了一下，林燕薇的脸上瞬间就飞上了红霞。

　　陈乘终于抬起来了头，不见丝毫惊讶，黑色的眸子紧紧盯着林燕薇，目光灼灼，反而是林燕薇被他这么看着有些不好意思了。

　　林燕薇想收回自己的脚，然而陈乘却不放，她只好费力地往回拉。

　　没料到陈乘突然松手，林燕薇用力过大，一下子就摔倒在地。

　　屁股摔了个结结实实，林燕薇揉着屁股抬头，竟看到陈乘脸上挂着明晃晃的笑，气恼地瞪了他一眼。

　　眨眼间陈乘就已经来到了林燕薇面前，抱起她就走进了最里面的书架。

　　林燕薇还没站稳，陈乘炙热而霸道的吻就铺天盖地般袭来。

第二章

　　唇舌交缠，牙齿碰撞，狂风席卷般的吻，似乎要卷走她肺内所有的空气。

　　林燕薇仅有的几次亲吻都是来自陈乘，还多是她主动的那种蜻蜓点水的浅浅的吻，经验几乎为零，陈乘吻得这么凶，过了没一会儿林燕薇就受不住了，心跳如雷，脸红如血，呼吸困难。

　　偏偏这是图书馆，林燕薇也不敢太大声，只能捶着陈乘的胸小声嗯哼。

　　陈乘却吻得更加热烈，控制不住地将林燕薇往怀里压了压，两个人的身体贴得更加密不可分。

　　被陈乘紧锢在怀里不得动弹，林燕薇只能被迫承受他的吻，直到最后感觉快上不来气了陈乘才放开她。

　　一接触到新鲜的空气，林燕薇连忙张开嘴大口呼吸。陈乘的呼吸也有些粗重，低头埋在她的脖颈中喘气平复。

　　陈乘将林燕薇紧紧拥在怀里，感受着她真实的体温。上次见面还是过年的时候，而今已是7月，没见到还好，这一见到只觉得发了疯地想她，想抱她，想亲她，情难自禁。

　　林燕薇还在喘气，陈乘就又忍不住去亲她的唇角，亲一下，再亲一下。

　　陈乘的眼神太过灼热，林燕薇的睫毛颤动了几下，双手攀上他的肩膀，踮起脚尖，主动凑上去亲了一下。

　　林燕薇这么一亲，陈乘只觉得头都快炸了，气血纷纷往上涌，搂在细腰上的手臂不自觉地加大了力道，转了个身就将林燕薇抵到了墙上，低头开始下一个疯狂的吻。

　　然而唇上一痛，林燕薇竟是咬了他的唇，捶着他的肩头开始激烈挣扎。

　　“快松开，屁股痛痛痛！”

　　林燕薇只穿着薄薄的裙子，刚摔到地上屁股可是还疼着呢，陈乘方才把她往墙上一压，林燕薇的屁股直接磕到了墙上，滋味酸爽，一时间哪还有什么旖旎的心思

　　林燕薇的眼中泛着水光，陈乘眉梢一皱，报复性地轻咬了下她的唇才松开手。

　　林燕薇早被吻得晕乎乎的，没有了陈乘的支撑，腿一软差点跌下去，幸好陈乘反应灵敏及时扶住了她。

　　但是陈乘的双手掐住林燕薇腋下的同时，大手好巧不巧地也落在了林燕薇的胸上，两人皆是一愣。

　　脸上一热，林燕薇又羞又恼，赶紧伸手推他，旋即就瞪大了眼，脸上的表情满是不可置信。

　　陈乘非但没有松开，反而还动手抓了抓，接下来甚至过分地伸出一只手从她的胸口摸了进去。

　　“陈乘你流氓！”

　　林燕薇话还没落音，陈乘的手里就已经多了两个厚厚的海面垫，坏心地戳了戳，她胸前立马塌进去了两块。

　　没想到陈乘居然就这么……

　　不知道该生气还是尴尬，林燕薇张了张嘴，迅速扭过去背对陈乘整理了下衣服，想要回来海绵他却已经塞进了兜里。

　　“陈乘你就会欺负我！”

　　“那你还大老远地跑过来？”

　　“我不是想着给你个生日惊喜么！”

'''
t=Text()
data= t.sentence_segmentation(paragraph)
data
# Out:
# ['\n\n酒吧里昏暗迷离，年轻男女们高歌曼舞尽情狂欢，酒后兴起玩幼稚游戏。',
#  '\n\n\u3000\u3000轮到陈乘大冒险，众人起哄和女伴打kiss。',
#  '\n\n\u3000\u3000林燕薇坐在一旁冷眼旁观，只见他晃晃悠悠起身走向别人，却骤然一转扭头捧住了她的脸。',
#  '\n\n\u3000\u3000突然的吻没有防备，抬眸便是他深邃的眉眼。',
#  '\n\n\u3000\u3000唇一触即离，不等林燕薇动手陈乘就主动退开，眼神迷离，笑容无辜又灿烂。',
#  '\n\n\u3000\u3000“对不起我喝多了，好像认错人了呢。',
#  '”\n\n\u3000\u3000当夜，林燕薇半梦半醒看窗外，男人正坐在她家窗户上吹冷风，指尖烟火明灭，发丝随风飞扬。',
#  '\n\n\u3000\u3000她起身过去关窗赶人，冷笑一声：“看来真的是喝多了，不仅人认错，连门都认错了。',
#  '\n\n\u3000\u3000“门没错，人也没错——”\n\n\u3000\u3000醉鬼却轰然倒在她身上，边胡乱亲她边可怜兮兮，“只是喝多了，更想你了……”\n\n\u3000\u3000内容标签：豪门世家 情有独钟 天作之合 娱乐圈\n\n\u3000\u3000主角：陈乘，林燕薇 ┃ 配角： ┃ 其它：\n\n第一章\n\n\u3000\u3000英国，剑桥。',
#  '\n\n\u3000\u3000刚刚下过一场雨，天色阴沉，人的心情也跟着有些沉闷。',
#  '\n\n\u3000\u3000图书馆门口人来人往，步履匆匆，偶尔微笑点头致意，继而又抱着各自的东西奔赴忙碌之中。',
#  '\n\n\u3000\u3000师生们一一持卡而入，井然有序，一旁的保安小哥百无聊赖，趁人不注意扭头打了个哈欠。',
#  '\n\n\u3000\u3000然而这一扭头，保安小哥无神的眼突然就亮了起来，哈欠才打了一半，嘴半张着忘了合拢，睁大了双眼呆呆地望着不远处的倩影。',
#  '\n\n\u3000\u3000只见一个美丽的东方面孔从门口款款走来，身材高挑，皮肤白皙，身着一袭红色吊带长裙，裙摆摇曳，明艳动人，看着她竟觉得她背后灰暗的天空都亮堂起来了。',
# ...

# %% [markdown]
# # 进行预测

# %%
# !pip3 install tqdm

# %%
import torch
from pytorch_pretrained_bert import BertTokenizer, BertForNextSentencePrediction
from Terry_toolkit import Text
#进度条显示
from tqdm import tqdm
import numpy as np
from random import *
class Nextsentence:
    def __init__(self,model='bert-base-chinese'):
        print('start NextSentence')
        self.tokeniser = BertTokenizer.from_pretrained(model)
        self.model = BertForNextSentencePrediction.from_pretrained(model)
        
    def one_sentence(self,data,previous_line):
        """
        文字数组中最符合的下一行
        
        返回内容为numpy
        
         items = np.array([['line_number','line_to_check','next_line_prediction']])
         
        
        >>> one_sentence(text_array,previous_line)
        
        >>> one_sentence(text_array,previous_line)
        
        """
#         items = np.array([['line_number','prediction','text']])
#         items = np.dtype([('line_number', int ),('prediction',  'S10'),('prediction',  'S10')]) 
        for line_number in tqdm(range(0, len(data)-1)):
#             print('line_number',line_number)
            
            #选取需要检测的内容
            line_to_check = data[line_number]
            #检查是否是相关
            next_line_prediction=self.predictions_check(previous_line,line_to_check)
#             print('line_to_check',line_to_check)
#             print('相关性指数',next_line_prediction)
            item = np.array([[line_number,line_to_check,next_line_prediction]])
            try:          
                items=np.r_[items,item]
            except:
                items= item
        #基于最后一个数据排序
        items=items[np.lexsort(items.T)]
        
        #倒序输出
        return np.flipud(items)
         
#         pass
    def predictions_check(self,previous_line,line_to_check):
        
            """
            检查两个语句是否是相似
            
            >>> predictions_check(previous_line,line_to_check)
            
            """


            len_line_1 = len(self.tokeniser.tokenize(previous_line))
            len_line_2 = len(self.tokeniser.tokenize(line_to_check))

            text = previous_line + ' ' + line_to_check

                #         print('text',text)
            tokenized_text = self.tokeniser.tokenize(text)
            #         print('tokenized_text',tokenized_text)

            indexed_tokens = self.tokeniser.convert_tokens_to_ids(tokenized_text)

            segments_ids = ([0] * len_line_1) + ([1] * len_line_2)
            tokens_tensor = torch.tensor([indexed_tokens])
            segments_tensors = torch.tensor([segments_ids])
            #         print('tokens_tensor',tokens_tensor)
            #         print('segments_tensors',segments_tensors)
            #这里使用模型进行预测
            predictions = self.model(tokens_tensor, segments_tensors)

            next_line_prediction = predictions[0,0].item()
            
            return next_line_prediction
    def text_to_array(self,text):
        """
        文字分句,文本转换成数组
        
        >>> text_to_array(text)
        
        """
        t=Text()
        data= t.sentence_segmentation(text)
        return data
    def sentence(self,text,previous_line):
        """
        获取文本中每句的可能性
        
        >>> sentence(text,previous_line)
        
        >>> sentence(text,previous_line)
        
        """
        paragraph_array=self.text_to_array(text)
        next_line=self.one_sentence(paragraph_array,previous_line)
        return next_line
    

        
        

nextS=Nextsentence()
# Out:
# start NextSentence

# %%
paragraph_array=nextS.text_to_array(paragraph)
#随机产生一句测试
num=randint(0,len(paragraph_array)-1)
previous_line = paragraph_array[num]
previous_line

# previous_line="腊肠犬名为 Dachshund，这个词最早起源于德国，在德语中是猎獾狗的意思，这名字一看就是个组合词，是由 Dachs（badger，“獾”）和 Hund（hound，“猎犬”）构成。由于腊肠犬腿短而身长，像极欧洲人民常吃的香肠热狗，所以人们又给它起了个绰号叫做香肠狗。"



# predictions=nextS.predictions_check('狗喜欢吃肉吗','拖拉机最好啦')
# print('predictions',predictions)

# paragraph_array=nextS.text_to_array(paragraph)
# next_line=nextS.one_sentence(paragraph_array,previous_line)
# print('next_line',next_line)
# Out:
# '\n\n\u3000\u3000林燕薇的脸红扑扑的，整理好衣服又从包里拿出小镜子照了照，这才挺了挺胸，左手轻轻捏着两只高跟鞋做兰花指状，迈着优雅的步伐朝楼上走去。'

# %% [markdown]
# ##  产生的数据进行排序

# %%
# data = next_line.sort()  #逆序
# data

# %%
# np.sort(next_line, axis =  0)
# data = next_line[:,next_line[1]]
# data
# next_line[:,1]
# sorted_x_index = np.argsort(next_line，axis=1) 
# sorted_x_index

# 按照概率大小排序
# new=next_line[np.lexsort(next_line.T)]
# np.flipud(new)

# next_line[np.lexsort(-next_line.T)]

# %%
#获取概率最大的一个
# new[-1]

# %%
previous_line
# Out:
# '\n\n或许它们不是小朋友最好的玩伴，如果小孩子冲它大吼大叫、在它面前来来回回奔跑戏弄于它，尤其是陌生的孩子，腊肠可能会发起攻击性行为。'

# %% [markdown]
# ## 获取符合的前十种可能

# %%
paragraph_array=nextS.text_to_array(paragraph)
#随机产生一句测试
num=randint(0,len(paragraph_array)-1)
previous_line = paragraph_array[num]
previous_line
print('前一句话:\n ',num,previous_line)
print('***'*40)
next_line=nextS.sentence(paragraph,previous_line)
print('next_line',next_line[:10])
# Out:
#   0%|          | 0/87 [00:00<?, ?it/s]
# 前一句话:
#   71 上次见面还是过年的时候，而今已是7月，没见到还好，这一见到只觉得发了疯地想她，想抱她，想亲她，情难自禁。
# ************************************************************************************************************************
# 100%|██████████| 87/87 [00:12<00:00,  7.88it/s]
# next_line [['60' '\n\n\u3000\u3000屁股摔了个结结实实，林燕薇揉着屁股抬头，竟看到陈乘脸上挂着明晃晃的笑，气恼地瞪了他一眼。'
#   '4.403454780578613']
#  ['41' '对面的座位正好空着，林燕薇就静静坐了过去，双手托腮看着陈乘，眼睛亮晶晶的，和看到偶像的迷妹没什么两样。'
#   '4.263864517211914']
#  ['45' '\n\n\u3000\u3000左摇摇，右晃晃，时不时有男人暧昧的视线投来，林燕薇只觉得没意思，趴在桌上望着陈乘鼓起了嘴。'
#   '4.21470308303833']
#  ['74'
#   '\n\n\u3000\u3000林燕薇这么一亲，陈乘只觉得头都快炸了，气血纷纷往上涌，搂在细腰上的手臂不自觉地加大了力道，转了个身就将林燕薇抵到了墙上，低头开始下一个疯狂的吻。'
#   '4.00815486907959']
#  ['25'
#   '\n\n\u3000\u3000想到之前和同伴聊天的时候曾讨论到亚洲的女人都比较委婉含蓄，保安小哥没有直接索要手机号码，而是绞尽脑汁来了一场美丽的开场白。'
#   '3.9793124198913574']
#  ['22'
#   '\n\n\u3000\u3000一步，两步，三步，眼看美人拿着卡就要从自己身边进去，四肢仿佛不听使唤一般，小保安意识到的时候已经拦到了她面前。'
#   '3.9372477531433105']
#  ['13'
# ...

# %%
print('前一句话:\n ',num,previous_line)
print('***'*40)
print('\n预测机率最大的前十句:\n',next_line[:10])
# Out:
# 前一句话:
#   71 上次见面还是过年的时候，而今已是7月，没见到还好，这一见到只觉得发了疯地想她，想抱她，想亲她，情难自禁。
# ************************************************************************************************************************
#
# 预测机率最大的前十句:
#  [['60' '\n\n\u3000\u3000屁股摔了个结结实实，林燕薇揉着屁股抬头，竟看到陈乘脸上挂着明晃晃的笑，气恼地瞪了他一眼。'
#   '4.403454780578613']
#  ['41' '对面的座位正好空着，林燕薇就静静坐了过去，双手托腮看着陈乘，眼睛亮晶晶的，和看到偶像的迷妹没什么两样。'
#   '4.263864517211914']
#  ['45' '\n\n\u3000\u3000左摇摇，右晃晃，时不时有男人暧昧的视线投来，林燕薇只觉得没意思，趴在桌上望着陈乘鼓起了嘴。'
#   '4.21470308303833']
#  ['74'
#   '\n\n\u3000\u3000林燕薇这么一亲，陈乘只觉得头都快炸了，气血纷纷往上涌，搂在细腰上的手臂不自觉地加大了力道，转了个身就将林燕薇抵到了墙上，低头开始下一个疯狂的吻。'
#   '4.00815486907959']
#  ['25'
#   '\n\n\u3000\u3000想到之前和同伴聊天的时候曾讨论到亚洲的女人都比较委婉含蓄，保安小哥没有直接索要手机号码，而是绞尽脑汁来了一场美丽的开场白。'
#   '3.9793124198913574']
#  ['22'
#   '\n\n\u3000\u3000一步，两步，三步，眼看美人拿着卡就要从自己身边进去，四肢仿佛不听使唤一般，小保安意识到的时候已经拦到了她面前。'
#   '3.9372477531433105']
#  ['13'
#   '\n\n\u3000\u3000只见一个美丽的东方面孔从门口款款走来，身材高挑，皮肤白皙，身着一袭红色吊带长裙，裙摆摇曳，明艳动人，看着她竟觉得她背后灰暗的天空都亮堂起来了。'
#   '3.9184885025024414']
# ...

# %%
np_array_to_list = next_line[:10].tolist()
import json
json.dumps(next_line[:10].tolist())
# Out:
# '[["60", "\\n\\n\\u3000\\u3000\\u5c41\\u80a1\\u6454\\u4e86\\u4e2a\\u7ed3\\u7ed3\\u5b9e\\u5b9e\\uff0c\\u6797\\u71d5\\u8587\\u63c9\\u7740\\u5c41\\u80a1\\u62ac\\u5934\\uff0c\\u7adf\\u770b\\u5230\\u9648\\u4e58\\u8138\\u4e0a\\u6302\\u7740\\u660e\\u6643\\u6643\\u7684\\u7b11\\uff0c\\u6c14\\u607c\\u5730\\u77aa\\u4e86\\u4ed6\\u4e00\\u773c\\u3002", "4.403454780578613"], ["41", "\\u5bf9\\u9762\\u7684\\u5ea7\\u4f4d\\u6b63\\u597d\\u7a7a\\u7740\\uff0c\\u6797\\u71d5\\u8587\\u5c31\\u9759\\u9759\\u5750\\u4e86\\u8fc7\\u53bb\\uff0c\\u53cc\\u624b\\u6258\\u816e\\u770b\\u7740\\u9648\\u4e58\\uff0c\\u773c\\u775b\\u4eae\\u6676\\u6676\\u7684\\uff0c\\u548c\\u770b\\u5230\\u5076\\u50cf\\u7684\\u8ff7\\u59b9\\u6ca1\\u4ec0\\u4e48\\u4e24\\u6837\\u3002", "4.263864517211914"], ["45", "\\n\\n\\u3000\\u3000\\u5de6\\u6447\\u6447\\uff0c\\u53f3\\u6643\\u6643\\uff0c\\u65f6\\u4e0d\\u65f6\\u6709\\u7537\\u4eba\\u66a7\\u6627\\u7684\\u89c6\\u7ebf\\u6295\\u6765\\uff0c\\u6797\\u71d5\\u8587\\u53ea\\u89c9\\u5f97\\u6ca1\\u610f\\u601d
# ...

# %%
predictions=nextS.predictions_check('狗喜欢吃肉吗','狗当然喜欢吃肉了')
print('predictions',predictions)

# %%
predictions=nextS.predictions_check('狗喜欢吃肉吗','狗最喜欢吃骨头了')
print('predictions',predictions)
# Out:
# predictions 3.233959436416626

# %%
# import urllib
# import json

    
poem_number = randint(0, len(data)-1)
print('poem_number',poem_number)


previous_line = data[poem_number]
# print('previous_line\n',previous_line.strip())

next_line_prediction = 0
threshold = 3
poems_picked = [poem_number]
print('poems_picked 选择那行内容开始',poems_picked)

#只写14句
for line_number in range(1, 14):
    next_line_prediction = 0
    #当筛选的语句到达14句停止
    while(line_number == len(poems_picked)):
        poem_number = randint(0, len(data)-1)
#         poem_number=poem_number+1
        line_to_check = data[poem_number]
#         print('line_to_check\n',line_to_check)
        
        len_line_1 = len(tokeniser.tokenize(previous_line))
        len_line_2 = len(tokeniser.tokenize(line_to_check))

        text = previous_line + ' ' + line_to_check
        
#         print('text',text)
        tokenized_text = tokeniser.tokenize(text)
#         print('tokenized_text',tokenized_text)

        indexed_tokens = tokeniser.convert_tokens_to_ids(tokenized_text)
  
        segments_ids = ([0] * len_line_1) + ([1] * len_line_2)
        tokens_tensor = torch.tensor([indexed_tokens])
        segments_tensors = torch.tensor([segments_ids])
#         print('tokens_tensor',tokens_tensor)
#         print('segments_tensors',segments_tensors)
        #这里使用模型进行预测
        predictions = model(tokens_tensor, segments_tensors)
        
        next_line_prediction = predictions[0,0].item()
        print('相关性指数',next_line_prediction)
        # No poem should be taken a line from more than once
        if poem_number not in poems_picked and next_line_prediction > threshold:
            
            #print('相关性较高')
            poems_picked = poems_picked + [poem_number]
            #print('poems_picked 已经被选择的内容编号',poems_picked)
        else:
            #print('不相关行号',poem_number)
            pass
    
    print('line_to_check 检测内容\n',line_to_check.strip())
    #重新基于新选择的内容预测下一句
    #优先选择最后三句
    if len(poems_picked)>4:
      previous_line =data[-3]+data[-2]+data[-1]
    else:
          
      previous_line = text
      
#     previous_line = line_to_check
#       print( poems_picked[-3])
    print('选择句子编号',poems_picked)

  
print('*'*100)
print('最终生成的内容\n\n')
last = ''
for i in poems_picked:
  last = last +data[i]+"\n"
print(last)
# Out:
# poem_number 22
# poems_picked 选择那行内容开始 [22]
# 相关性指数 0.5738663077354431
# 相关性指数 2.7135181427001953
# 相关性指数 3.7259256839752197
# line_to_check 检测内容
#  犬细小病毒病：本病是近几年分别发现由病畜的粪、尿，唾液等感染的犬科动物传染病。
# 选择句子编号 [22, 50]
# 相关性指数 1.3665878772735596
# 相关性指数 1.6812564134597778
# 相关性指数 1.7113006114959717
# 相关性指数 2.9395155906677246
# 相关性指数 2.3588674068450928
# 相关性指数 3.6418778896331787
# line_to_check 检测内容
#  有明显的肺炎征兆。
# 选择句子编号 [22, 50, 77]
# 相关性指数 1.3565011024475098
# 相关性指数 3.6934871673583984
# line_to_check 检测内容
#  病犬阵发性 肌肉僵直或抽搐，角弓反张。
# 选择句子编号 [22, 50, 77, 70]
# 相关性指数 3.1884193420410156
# line_to_check 检测内容
#  毛刷只能使长毛的末端蓬松，而细茸毛却梳不到。
# 选择句子编号 [22, 50, 77, 70, 36]
# 相关性指数 3.095076560974121
# line_to_check 检测内容
#  性格特征编辑
# 本性友好，勇敢大胆，既不胆怯也不凶残，性格温和 [1]  。
# 选择句子编号 [22, 50, 77, 70, 36, 20]
# 相关性指数 4.144028663635254
# line_to_check 检测内容
#  狂犬病弱毒细胞冻干苗，用灭菌水稀释后，不论犬只大小，一律皮下注射1毫升，免疫期1年。
# 选择句子编号 [22, 50, 77, 70, 36, 20, 40]
# 相关性指数 3.4318222999572754
# line_to_check 检测内容
#  后驱的肌肉发达且结实，但宽度略小于肩部。
# ...

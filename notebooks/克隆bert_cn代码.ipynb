# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
# with open('/gdrive/My Drive/foo.txt', 'w') as f:
#   f.write('Hello Google Drive!')
# !cat '/gdrive/My Drive/foo.txt'

# %%
# %cd /gdrive/My Drive/bert
# Out:
# /gdrive/My Drive/bert

# %%
# !rm -rf bert-cn

# %%
# !git clone https://github.com/napoler/bert-cn.git
# Out:
# Cloning into 'bert-cn'...
# remote: Enumerating objects: 487, done.
# remote: Counting objects: 100% (487/487), done.
# remote: Compressing objects: 100% (327/327), done.
# remote: Total 487 (delta 182), reused 424 (delta 127), pack-reused 0
# Receiving objects: 100% (487/487), 16.61 MiB | 9.67 MiB/s, done.
# Resolving deltas: 100% (182/182), done.
# Checking out files: 100% (178/178), done.

# %%
# !ls
# Out:
# bert-cn  data

# %%
cd bert-cn/
# Out:
# /gdrive/My Drive/bert/bert-cn

# %%
# !ls
# Out:
# data  dev.md  docs  examples  LICENSE  notebooks  README.md  src  train_cn

# %%
# !git branch -a
# Out:
# * master
#   remotes/origin/0.62
#   remotes/origin/HEAD -> origin/master
#   remotes/origin/master
#   remotes/origin/v6.1

# %%
! git checkout remotes/origin/0.62
# Out:
# error: Your local changes to the following files would be overwritten by checkout:
# 	src/pytorch_pretrained_bert/convert_gpt2_checkpoint_to_pytorch.py
# 	src/pytorch_pretrained_bert/convert_openai_checkpoint_to_pytorch.py
# 	src/pytorch_pretrained_bert/convert_tf_checkpoint_to_pytorch.py
# 	src/pytorch_pretrained_bert/convert_transfo_xl_checkpoint_to_pytorch.py
# Please commit your changes or stash them before you switch branches.
# Aborting

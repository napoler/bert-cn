# %%
# !python3 -m pip install jupyterlab
# Out:
# ...
#      |████████████████████████████████| 14.8MB 2.8MB/s
# ...

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
# with open('/gdrive/My Drive/foo.txt', 'w') as f:
#   f.write('Hello Google Drive!')
# !cat '/gdrive/My Drive/foo.txt'

# %% [markdown]
# # 执行这里运行jupyter lab服务器

# %%
# %cd /
# !jupyter lab --allow-root  --config=/gdrive/My\ Drive/bert/bert-cn/tools/jupyter_notebook_config.py
# Out:
# /
# [I 20:32:37.203 LabApp] google.colab serverextension initialized.
# [W 20:32:37.203 LabApp] JupyterLab server extension not enabled, manually loading...
# [I 20:32:37.207 LabApp] JupyterLab extension loaded from /usr/local/lib/python3.6/dist-packages/jupyterlab
# [I 20:32:37.207 LabApp] JupyterLab application directory is /usr/local/share/jupyter/lab
# [I 20:32:37.209 LabApp] Serving notebooks from local directory: /
# [I 20:32:37.209 LabApp] 0 active kernels
# [I 20:32:37.210 LabApp] The Jupyter Notebook is running at:
# [I 20:32:37.210 LabApp] http://localhost:8888/
# [I 20:32:37.210 LabApp] Use Control-C to stop this server and shut down all kernels (twice to skip confirmation).
# [W 20:32:37.210 LabApp] No web browser found: could not locate runnable browser.
# [I 20:32:45.552 LabApp] 302 POST /login?next=%2Flab%3F (::1) 1.99ms
# [I 20:32:45.555 LabApp] 302 POST /login?next=%2Flab%3F (::1) 1.05ms
# [I 20:32:45.557 LabApp] 302 POST /login?next=%2Flab%3F (::1) 0.94ms
# ...

# %% [markdown]
# ## 设置密码

# %%
# !jupyter notebook password
# Out:
# Enter password:
# Verify password:
# [NotebookPasswordApp] Wrote hashed password to /root/.jupyter/jupyter_notebook_config.json

# %%
# !cp /root/.jupyter/jupyter_notebook_config.json /gdrive/My\ Drive/bert/bert-cn/tools/

# %%
# %writefile code.py
# Out:
# UsageError: Line magic function `%writefile` not found (But cell magic `%%writefile` exists, did you mean that instead?).

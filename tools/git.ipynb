# %%
# %cd /gdrive/My\ Drive/bert/bert-cn/
# Out:
# /gdrive/My Drive/bert/bert-cn

# %%
# !git add .
# Out:
# error: open("requirements.gdoc"): Operation not supported
# error: unable to index file requirements.gdoc
# fatal: adding files failed

# %%
# !git config --global user.email "napoler2008@gmail.com"
# !git config --global user.name "Terry Chan"

# %%
# !git commit -m "提交"
# Out:
# On branch master
# Your branch is up to date with 'origin/master'.
#
# Changes not staged for commit:
# 	modified:   examples/lm_finetuning/simple_lm_finetuning.py
# 	modified:   examples/run_squad_cn_62.py
# 	modified:   "examples/run_squad_cn\350\277\220\350\241\214\346\234\254\345\234\260\346\250\241\345\236\213.ipynb"
# 	modified:   "notebooks/\351\227\256\347\255\224.ipynb"
# 	modified:   requirements.txt
# 	deleted:    tools/Untitled1.ipynb
# 	modified:   "tools/\345\256\211\350\243\205jupyterlab.ipynb"
# 	modified:   "\345\210\235\345\247\213\345\214\226\346\234\215\345\212\241.ipynb"
#
# Untracked files:
# 	bert_server/simple_lm_finetuning.ipynb
# 	bert_server/simple_lm_finetuning.py
# 	requirements.gdoc
# 	tools/git.ipynb
#
# no changes added to commit

# %%
#使用命令行执行
# !git push
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# %cd .git
# Out:
# /gdrive/My Drive/bert/bert-cn/.git

# %%
# !ls
# Out:
# branches	config	     HEAD   index  logs     packed-refs
# COMMIT_EDITMSG	description  hooks  info   objects  refs

# %%
# !cat config
# Out:
# [core]
# 	repositoryformatversion = 0
# 	filemode = true
# 	bare = false
# 	logallrefupdates = true
# 	symlinks = false
# [remote "origin"]
# 	url = https://github.com/napoler/bert-cn.git
# 	fetch = +refs/heads/*:refs/remotes/origin/*
# [branch "master"]
# 	remote = origin
# 	merge = refs/heads/master
